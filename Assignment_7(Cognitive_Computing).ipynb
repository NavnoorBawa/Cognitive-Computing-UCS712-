# %% [markdown]
# ***Q1***

# %% [markdown]
# ***PART 1***

# %% [markdown]
# ***1***

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
roll_no =  102317164
np.random.seed(roll_no)

# %% [markdown]
# ***2***

# %%
sales_data = np.random.randint(1000, 5000, size=(12, 4))

# %% [markdown]
# ***3***

# %%
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
categories = ['Electronics', 'Clothing', 'Home & Kitchen', 'Sports']
df = pd.DataFrame(sales_data, columns=categories, index=months)
df
# Out:
#      Electronics  Clothing  Home & Kitchen  Sports
# Jan         4652      1054            1306    3704
# Feb         3567      3711            3890    2763
# Mar         1339      4903            2205    2702
# Apr         4537      3218            2762    2905
# May         1026      4704            3516    1887
# Jun         4909      1368            4727    1330
# Jul         4239      4143            4594    4892
# Aug         4497      1478            1418    3572
# Sep         2773      4407            3379    1544
# Oct         2411      1694            2908    1121
# Nov         3511      4253            3382    2981
# Dec         4579      2823            3131    2289

# %% [markdown]
# ***PART 2***

# %%
print("First 5 rows of DataFrame:\n", df.head())
print("\nSummary Statistics:\n", df.describe())
# Out:
# First 5 rows of DataFrame:
#       Electronics  Clothing  Home & Kitchen  Sports
# Jan         4652      1054            1306    3704
# Feb         3567      3711            3890    2763
# Mar         1339      4903            2205    2702
# Apr         4537      3218            2762    2905
# May         1026      4704            3516    1887
#
# Summary Statistics:
#         Electronics     Clothing  Home & Kitchen       Sports
# count    12.000000    12.000000       12.000000    12.000000
# mean   3503.333333  3146.333333     3101.500000  2640.833333
# std    1334.903765  1420.019355     1080.164676  1095.137254
# min    1026.000000  1054.000000     1306.000000  1121.000000
# 25%    2682.500000  1640.000000     2622.750000  1801.250000
# 50%    3903.000000  3464.500000     3255.000000  2732.500000
# 75%    4547.500000  4291.500000     3609.500000  3128.750000
# max    4909.000000  4903.000000     4727.000000  4892.000000

# %%
total_sales_category = df.sum()
print("\nTotal Sales per Category:\n", total_sales_category)
# Out:
# Total Sales per Category:
#  Electronics       42040
# Clothing          37756
# Home & Kitchen    37218
# Sports            31690
# dtype: int64

# %%
df['Total Sales'] = df.sum(axis=1)
df
# Out:
#      Electronics  Clothing  Home & Kitchen  Sports  Total Sales
# Jan         4652      1054            1306    3704        10716
# Feb         3567      3711            3890    2763        13931
# Mar         1339      4903            2205    2702        11149
# Apr         4537      3218            2762    2905        13422
# May         1026      4704            3516    1887        11133
# Jun         4909      1368            4727    1330        12334
# Jul         4239      4143            4594    4892        17868
# Aug         4497      1478            1418    3572        10965
# Sep         2773      4407            3379    1544        12103
# Oct         2411      1694            2908    1121         8134
# Nov         3511      4253            3382    2981        14127
# Dec         4579      2823            3131    2289        12822

# %%
df['Growth Rate'] = df['Total Sales'].pct_change() * 100
df
# Out:
#      Electronics  Clothing  Home & Kitchen  Sports  Total Sales  Growth Rate
# Jan         4652      1054            1306    3704        10716          NaN
# Feb         3567      3711            3890    2763        13931    30.001866
# Mar         1339      4903            2205    2702        11149   -19.969851
# Apr         4537      3218            2762    2905        13422    20.387479
# May         1026      4704            3516    1887        11133   -17.054090
# Jun         4909      1368            4727    1330        12334    10.787748
# Jul         4239      4143            4594    4892        17868    44.867845
# Aug         4497      1478            1418    3572        10965   -38.633311
# Sep         2773      4407            3379    1544        12103    10.378477
# Oct         2411      1694            2908    1121         8134   -32.793522
# Nov         3511      4253            3382    2981        14127    73.678387
# Dec         4579      2823            3131    2289        12822    -9.237630

# %%
df['Electronics'] = df['Electronics'] * 0.9
df
# Out:
#      Electronics  Clothing  Home & Kitchen  Sports  Total Sales  Growth Rate
# Jan       4186.8      1054            1306    3704        10716          NaN
# Feb       3210.3      3711            3890    2763        13931    30.001866
# Mar       1205.1      4903            2205    2702        11149   -19.969851
# Apr       4083.3      3218            2762    2905        13422    20.387479
# May        923.4      4704            3516    1887        11133   -17.054090
# Jun       4418.1      1368            4727    1330        12334    10.787748
# Jul       3815.1      4143            4594    4892        17868    44.867845
# Aug       4047.3      1478            1418    3572        10965   -38.633311
# Sep       2495.7      4407            3379    1544        12103    10.378477
# Oct       2169.9      1694            2908    1121         8134   -32.793522
# Nov       3159.9      4253            3382    2981        14127    73.678387
# Dec       4121.1      2823            3131    2289        12822    -9.237630

# %% [markdown]
# ***PART 3***

# %%
plt.figure(figsize=(10, 6))
for category in categories:
    plt.plot(df.index, df[category], label=category)
plt.xlabel('Months')
plt.ylabel('Sales')
plt.title('Monthly Sales Trends')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=df[categories])
plt.title('Sales Distribution by Category')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_base.py:1447: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.plot_data[axis] = cat_data

# %% [markdown]
# ***Q2***

# %%
array = np.array([[1, -2, 3],[-4, 5, -6]])

# %%
np.abs(array)
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
flat = array.flatten()
flat
# Out:
# array([ 1, -2,  3, -4,  5, -6])

# %%
np.percentile(flat,[25,50,75])
# Out:
# array([-3.5, -0.5,  2.5])

# %%
np.percentile(array,[25,50,75],axis=0)
# Out:
# array([[-2.75, -0.25, -3.75],
#        [-1.5 ,  1.5 , -1.5 ],
#        [-0.25,  3.25,  0.75]])

# %%
np.percentile(array,[25,50,75],axis=1)
# Out:
# array([[-0.5, -5. ],
#        [ 1. , -4. ],
#        [ 2. ,  0.5]])

# %%
print(np.mean(flat))
print(np.median(flat))
print(np.std(flat))
# Out:
# -0.5
# -0.5
# 3.8622100754188224

# %%
print(np.mean(array,axis=0))
print(np.median(array,axis=0))
print(np.std(array,axis=0))
# Out:
# [-1.5  1.5 -1.5]
# [-1.5  1.5 -1.5]
# [2.5 3.5 4.5]

# %%
print(np.mean(array,axis=1))
print(np.median(array,axis=1))
print(np.std(array,axis=1))
# Out:
# [ 0.66666667 -1.66666667]
# [ 1. -4.]
# [2.05480467 4.78423336]

# %% [markdown]
# ***Q3***

# %%
a = np.array([-1.8, -1.6, -0.5, 0.5,1.6, 1.8, 3.0])

# %%
print("Floor:", np.floor(a))
print("Ceiling:", np.ceil(a))
print("Truncated:", np.trunc(a))
print("Rounded:", np.round(a))
# Out:
# Floor: [-2. -2. -1.  0.  1.  1.  3.]
# Ceiling: [-1. -1. -0.  1.  2.  2.  3.]
# Truncated: [-1. -1. -0.  0.  1.  1.  3.]
# Rounded: [-2. -2. -0.  0.  2.  2.  3.]

# %% [markdown]
# ***Q4***

# %%
def swap_list_elements(lst, pos1, pos2):
    temp = lst[pos1]
    lst[pos1] = lst[pos2]
    lst[pos2] = temp
    return lst

lst = [1, 2, 3, 4, 5]
print("Swapped List:", swap_list_elements(lst, 1, 3))
# Out:
# Swapped List: [1, 4, 3, 2, 5]

# %% [markdown]
# ***Q5***

# %%
def swap_set_elements(s, pos1, pos2):
    s_list = list(s)
    s_list[pos1], s_list[pos2] = s_list[pos2], s_list[pos1]
    return set(s_list)

s = {10, 20, 30, 40, 50}
print("Swapped Set:", swap_set_elements(s, 0, 3))
# Out:
# Swapped Set: {40, 10, 50, 20, 30}
